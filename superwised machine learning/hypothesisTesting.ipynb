# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %%
pop_data = [np.random.randint(10,100) for i in range (1000)]

# %%
pop_table = pd.DataFrame(pop_data, columns=['Population'])

# %%
np.mean(pop_data)
plt.figure(figsize=(4,3))
sns.kdeplot(x='Population',data=pop_table)
plt.show()
# Out:
# np.float64(54.933)

# %%
plt.figure(figsize=(4,3))
sns.kdeplot(x='Population',data=pop_table)
plt.show()

# %%
sample_mean = []

# %%
for no_sample in range(60):
  sample_data = []
  for i in range(500):
    sample_data.append(np.random.choice(pop_data, size=100).mean())
  sample_mean.append(np.mean(sample_data))

# %%
np.mean(sample_mean)
# Out:
# np.float64(54.908628666666665)

# %%
plt.figure(figsize=(4,3))
sample_M = pd.DataFrame({'sample_mean':sample_mean})
sns.kdeplot(x='sample_mean',data=sample_M)
plt.show()

# %%
import scipy.stats as st

# %%
s_x = 90
P_u = 82
p_std = 20
n = 81
ap = 0.05

# %%
z_cal = (s_x-P_u)/(p_std/np.sqrt(n))
z_cal
# Out:
# np.float64(3.5999999999999996)

# %%
z_table=st.norm.ppf(1-ap)
z_table
# Out:
# np.float64(1.6448536269514722)

# %%
if z_cal > z_table:
  print('Reject Null Hypothesis')
  print('Accept Alternate Hypothesis')
  print('Mean is not equal to 82')
  print('ha is right')
else:
  print('Accept Null Hypothesis')
  print('reject Alternate Hypothesis')
# Out:
# Reject Null Hypothesis
# Accept Alternate Hypothesis
# Mean is not equal to 82
# ha is right

# %%
# Input fields
s_x = 6564 #@param {type:"number"}
p_u = 154655 #@param {type:"number"}
p_std = 2122 #@param {type:"number"}
n = 1231 #@param {type:"number"}
ap = 1.5 #@param {type:"number"}

z_cal = (s_x - p_u) / (p_std / np.sqrt(n))
z_table = st.norm.ppf(1 - ap)

print(f"Calculated Z-score: {z_cal}")
print(f"Z-score from table: {z_table}")

if z_cal > z_table:
  print('Reject Null Hypothesis')
  print('Accept Alternate Hypothesis')
  print('Mean is not equal to', p_u)
  print('ha is right')
else:
  print('Accept Null Hypothesis')
  print('Reject Alternate Hypothesis')
# Out:
# Calculated Z-score: -2448.5688073306096
# Z-score from table: nan
# Accept Null Hypothesis
# Reject Alternate Hypothesis

# %%
t_table = st.t.ppf(1-0.025,19)
t_table
# Out:
# np.float64(2.093024054408263)

# %%
Before = np.array([ 50,60,45,65,55,70,40,75,80,65,70,60,50,55,45,75,60,50,65,70])
After = np.array([ 60,70,55,75,65,80,50,85,99,70,75,65,55,60,50,80,65,55,70,75])
# Out:
# 20

# %%
std_after = np.square(np.std(After))/len(After)
std_before = np.square(np.std(Before))/len(Before)

# %%
t_cal = (np.mean(After)-np.mean(Before))/np.sqrt(std_after+std_before)
t_cal
# Out:
# np.float64(2.089742689617797)
