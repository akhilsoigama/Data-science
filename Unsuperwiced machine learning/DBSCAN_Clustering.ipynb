# %% [markdown]
# **DBSCAN Clustering**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons
import pandas as pd

# %%
x,y = make_moons(n_samples=250, noise=0.05)

# %%
df = {'data1':x[:,0], 'data2':x[:,1]}
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#       data1     data2
# 0  0.065453  1.006645
# 1  1.833765  0.005395
# 2  1.601192 -0.294497
# 3  0.908638  0.328224
# 4  0.624541  0.812285

# %%
sns.scatterplot(data=df, x='data1', y='data2')
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
db = DBSCAN(eps=0.2, min_samples=5)
df['predict'] = db.fit_predict(df)

# %%
sns.scatterplot(data=df, x='data1', y='data2', hue='predict')
plt.show()
